# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
TRAIN_DIR= 'images/train'
TEST_DIR= 'images/test'

# %%
#From the images provided in the dataset we will create a data frame.
# columns = image, label

def createDataFrame(dir):
    '''
        directory denge train aur test ki.
        jo bhi folder hai train(say) ke andar unko list kar dega say angry, sad, happy, etc.,
        We will treat each folder as a label.
        This happens in label for loop.

        Next in the imagename for loop, each image in the labelled folder is traversed through.
        That image name is added to image_paths. So image_paths stores the whole path of the image.
        
        
    '''
    image_paths= []
    labels=[]
    for label in os.listdir(dir): #the dir is basically the path till images. os.listdir will find the contents of the image folder. Label will store the sub-folders present in image folder. 
        for imagename in os.listdir( os.path.join(dir,label)): #traverses each image present in the label folder. Say traverse each image present in the angry folder.
            image_paths.append(os.path.join(dir,label,imagename)) #a path is created .../image/angry/img0013
            labels.append(label) # in labels list, the particular label is appended. Say angry. So label stores all the emotions present.
        print(label," added to DataFrame")
    return image_paths,labels #image_paths contain the full path, labels contain the emotion.

# %%
train= pd.DataFrame()
train['image'], train['label'] = createDataFrame(TRAIN_DIR)
# Out:
# angry  added to DataFrame
# disgust  added to DataFrame
# fear  added to DataFrame
# happy  added to DataFrame
# neutral  added to DataFrame
# sad  added to DataFrame
# surprise  added to DataFrame

# %%
train #all the training images'-paths and their respective labels are stored in the train dataframe.
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test= pd.DataFrame()
test['image'], test['label'] = createDataFrame(TEST_DIR)
# Out:
# angry  added to DataFrame
# disgust  added to DataFrame
# fear  added to DataFrame
# happy  added to DataFrame
# neutral  added to DataFrame
# sad  added to DataFrame
# surprise  added to DataFrame

# %%
test
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]

# %%
from tqdm.notebook import tqdm

# %%
def extractFeatures(images): 
    '''
    Now we will pick apart each image and perform feature extraction on them.
    The images being received as input to the function will contain dataFrame.image column only i.e., all the paths of the images.
    The tqdm module helps in accessing all the images that are present in the image path. 
    For loop wala image only contains the path that have been mentioned in the 
    images list. To see the progress of each image present int the path, we use tqdm module.
    '''
    features=[] #the features extracted through the image will be put in this list.
    for image in tqdm(images): #will traverse every image whose path have been provided in the images.
        img= load_img(image, grayscale=True) #converted the image to grayscale as it takes only 1 channel for processing whereas the classic RGB takes 3 channels that at times can become complex.
        img = np.array(img) #image is converted to array
        features.append(img) 
    features= np.array(features) #convert features to array.
    features= features.reshape(len(features), 48,48,1) #length, image width,image height, image depth=1 as its 2D
    return features

# %%
train_features= extractFeatures(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# C:\Users\KIIT\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
test_features= extractFeatures(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0 #(divided by highest pixel value = 255)
x_test= test_features/255.0

# %%
#to make label we use labelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train= le.transform(train['label'])
y_test= le.transform(test['label'])

# %%
y_train= to_categorical(y_train, num_classes= 7)
y_test= to_categorical(y_test, num_classes=7)

# %%
model= Sequential()

#cnn layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer, 7= number of classes
model.add(Dense(7, activation='softmax'))
# Out:
# C:\Users\KIIT\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
#model.compile(optimizer= 'adam', loss= 'categorical_crossentropy', metrics= 'accuracy')\

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'] )

# %%
model.fit(x=x_train, y=y_train, batch_size=128, epochs=100, validation_data= (x_test, y_test))
# Out:
# Epoch 1/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 147s 637ms/step - accuracy: 0.2338 - loss: 1.8407 - val_accuracy: 0.2583 - val_loss: 1.8168
# Epoch 2/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 141s 624ms/step - accuracy: 0.2535 - loss: 1.8049 - val_accuracy: 0.2613 - val_loss: 1.7820
# Epoch 3/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 164s 726ms/step - accuracy: 0.2709 - loss: 1.7563 - val_accuracy: 0.3394 - val_loss: 1.6289
# Epoch 4/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 165s 733ms/step - accuracy: 0.3412 - loss: 1.6424 - val_accuracy: 0.4420 - val_loss: 1.4488
# Epoch 5/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 178s 786ms/step - accuracy: 0.4080 - loss: 1.5127 - val_accuracy: 0.4727 - val_loss: 1.3613
# Epoch 6/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 169s 746ms/step - accuracy: 0.4355 - loss: 1.4577 - val_accuracy: 0.4936 - val_loss: 1.3114
# Epoch 7/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7106s 32s/step - accuracy: 0.4599 - loss: 1.3981 - val_accuracy: 0.5156 - val_loss: 1.2649
# Epoch 8/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 164s 727ms/step - accuracy: 0.4804 - loss: 1.3519 - val_accuracy: 0.5180 - val_loss: 1.2652
# Epoch 9/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 164s 727ms/step - accuracy: 0.4852 - loss: 1.3384 - val_accuracy: 0.5401 - val_loss: 1.2263
# Epoch 10/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 711ms/step - accuracy: 0.4988 - loss: 1.3088 - val_accuracy: 0.5419 - val_loss: 1.1989
# Epoch 11/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 158s 701ms/step - accuracy: 0.5053 - loss: 1.2926 - val_accuracy: 0.5313 - val_loss: 1.2260
# Epoch 12/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 517s 2s/step - accuracy: 0.5198 - loss: 1.2700 - val_accuracy: 0.5609 - val_loss: 1.1654
# Epoch 13/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 164s 725ms/step - accuracy: 0.5171 - loss: 1.2576 - val_accuracy: 0.5647 - val_loss: 1.1496
# Epoch 14/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 163s 723ms/step - accuracy: 0.5358 - loss: 1.2313 - val_accuracy: 0.5645 - val_loss: 1.1565
# Epoch 15/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 162s 715ms/step - accuracy: 0.5334 - loss: 1.2223 - val_accuracy: 0.5676 - val_loss: 1.1460
# Epoch 16/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 164s 724ms/step - accuracy: 0.5453 - loss: 1.2053 - val_accuracy: 0.5742 - val_loss: 1.1264
# Epoch 17/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 163s 720ms/step - accuracy: 0.5444 - loss: 1.1925 - val_accuracy: 0.5723 - val_loss: 1.1358
# Epoch 18/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 163s 720ms/step - accuracy: 0.5420 - loss: 1.1916 - val_accuracy: 0.5894 - val_loss: 1.1071
# Epoch 19/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 163s 720ms/step - accuracy: 0.5508 - loss: 1.1783 - val_accuracy: 0.5845 - val_loss: 1.1076
# Epoch 20/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 163s 722ms/step - accuracy: 0.5584 - loss: 1.1684 - val_accuracy: 0.5821 - val_loss: 1.1169
# Epoch 21/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 711ms/step - accuracy: 0.5631 - loss: 1.1491 - val_accuracy: 0.5877 - val_loss: 1.0962
# Epoch 22/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 711ms/step - accuracy: 0.5672 - loss: 1.1439 - val_accuracy: 0.5928 - val_loss: 1.0947
# Epoch 23/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 7688s 34s/step - accuracy: 0.5764 - loss: 1.1186 - val_accuracy: 0.5935 - val_loss: 1.0917
# Epoch 24/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 160s 709ms/step - accuracy: 0.5683 - loss: 1.1329 - val_accuracy: 0.5805 - val_loss: 1.1074
# Epoch 25/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 160s 709ms/step - accuracy: 0.5801 - loss: 1.1195 - val_accuracy: 0.5926 - val_loss: 1.0919
# Epoch 26/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 158s 701ms/step - accuracy: 0.5791 - loss: 1.1098 - val_accuracy: 0.5974 - val_loss: 1.0938
# Epoch 27/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 158s 700ms/step - accuracy: 0.5773 - loss: 1.1083 - val_accuracy: 0.5986 - val_loss: 1.0752
# Epoch 28/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 159s 703ms/step - accuracy: 0.5901 - loss: 1.0874 - val_accuracy: 0.6015 - val_loss: 1.0651
# Epoch 29/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 712ms/step - accuracy: 0.5943 - loss: 1.0765 - val_accuracy: 0.6015 - val_loss: 1.0655
# Epoch 30/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 167s 740ms/step - accuracy: 0.5980 - loss: 1.0677 - val_accuracy: 0.6036 - val_loss: 1.0745
# Epoch 31/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.5946 - loss: 1.0738 - val_accuracy: 0.6029 - val_loss: 1.0631
# Epoch 32/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - accuracy: 0.6027 - loss: 1.0555 - val_accuracy: 0.6035 - val_loss: 1.0632
# Epoch 33/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.6013 - loss: 1.0575 - val_accuracy: 0.5992 - val_loss: 1.0739
# Epoch 34/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6061 - loss: 1.0478 - val_accuracy: 0.6074 - val_loss: 1.0587
# Epoch 35/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 295s 1s/step - accuracy: 0.6039 - loss: 1.0515 - val_accuracy: 0.6060 - val_loss: 1.0576
# Epoch 36/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 300s 1s/step - accuracy: 0.6052 - loss: 1.0411 - val_accuracy: 0.5993 - val_loss: 1.0899
# Epoch 37/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 293s 1s/step - accuracy: 0.6107 - loss: 1.0300 - val_accuracy: 0.6042 - val_loss: 1.0575
# Epoch 38/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 305s 1s/step - accuracy: 0.6092 - loss: 1.0359 - val_accuracy: 0.6101 - val_loss: 1.0440
# Epoch 39/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - accuracy: 0.6166 - loss: 1.0239 - val_accuracy: 0.6107 - val_loss: 1.0493
# Epoch 40/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.6243 - loss: 1.0063 - val_accuracy: 0.6067 - val_loss: 1.0477
# Epoch 41/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 182s 806ms/step - accuracy: 0.6281 - loss: 1.0042 - val_accuracy: 0.6149 - val_loss: 1.0440
# Epoch 42/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 176s 777ms/step - accuracy: 0.6205 - loss: 1.0049 - val_accuracy: 0.6112 - val_loss: 1.0464
# Epoch 43/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 175s 776ms/step - accuracy: 0.6241 - loss: 0.9966 - val_accuracy: 0.6169 - val_loss: 1.0417
# Epoch 44/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 228s 1s/step - accuracy: 0.6291 - loss: 0.9971 - val_accuracy: 0.6091 - val_loss: 1.0555
# Epoch 45/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.6313 - loss: 0.9808 - val_accuracy: 0.6124 - val_loss: 1.0458
# Epoch 46/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.6349 - loss: 0.9792 - val_accuracy: 0.6235 - val_loss: 1.0317
# Epoch 47/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.6352 - loss: 0.9658 - val_accuracy: 0.6214 - val_loss: 1.0292
# Epoch 48/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 233s 1s/step - accuracy: 0.6440 - loss: 0.9612 - val_accuracy: 0.6169 - val_loss: 1.0361
# Epoch 49/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - accuracy: 0.6398 - loss: 0.9639 - val_accuracy: 0.6169 - val_loss: 1.0395
# Epoch 50/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 233s 1s/step - accuracy: 0.6403 - loss: 0.9550 - val_accuracy: 0.6144 - val_loss: 1.0433
# Epoch 51/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.6497 - loss: 0.9393 - val_accuracy: 0.6271 - val_loss: 1.0234
# Epoch 52/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 239s 1s/step - accuracy: 0.6471 - loss: 0.9398 - val_accuracy: 0.6189 - val_loss: 1.0449
# Epoch 53/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.6423 - loss: 0.9535 - val_accuracy: 0.6219 - val_loss: 1.0294
# Epoch 54/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.6485 - loss: 0.9268 - val_accuracy: 0.6179 - val_loss: 1.0329
# Epoch 55/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.6453 - loss: 0.9403 - val_accuracy: 0.6274 - val_loss: 1.0306
# Epoch 56/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - accuracy: 0.6528 - loss: 0.9212 - val_accuracy: 0.6200 - val_loss: 1.0314
# Epoch 57/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 276s 1s/step - accuracy: 0.6638 - loss: 0.9190 - val_accuracy: 0.6230 - val_loss: 1.0376
# Epoch 58/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - accuracy: 0.6567 - loss: 0.9218 - val_accuracy: 0.6173 - val_loss: 1.0266
# Epoch 59/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 277s 1s/step - accuracy: 0.6570 - loss: 0.9208 - val_accuracy: 0.6243 - val_loss: 1.0279
# Epoch 60/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - accuracy: 0.6655 - loss: 0.9117 - val_accuracy: 0.6298 - val_loss: 1.0206
# Epoch 61/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 274s 1s/step - accuracy: 0.6639 - loss: 0.8983 - val_accuracy: 0.6230 - val_loss: 1.0338
# Epoch 62/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.6692 - loss: 0.8918 - val_accuracy: 0.6224 - val_loss: 1.0250
# Epoch 63/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 240s 1s/step - accuracy: 0.6731 - loss: 0.8856 - val_accuracy: 0.6274 - val_loss: 1.0110
# Epoch 64/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 162s 716ms/step - accuracy: 0.6746 - loss: 0.8824 - val_accuracy: 0.6210 - val_loss: 1.0203
# Epoch 65/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 713ms/step - accuracy: 0.6764 - loss: 0.8615 - val_accuracy: 0.6204 - val_loss: 1.0262
# Epoch 66/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 162s 717ms/step - accuracy: 0.6799 - loss: 0.8693 - val_accuracy: 0.6209 - val_loss: 1.0239
# Epoch 67/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 164s 727ms/step - accuracy: 0.6726 - loss: 0.8851 - val_accuracy: 0.6244 - val_loss: 1.0254
# Epoch 68/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 164s 726ms/step - accuracy: 0.6767 - loss: 0.8697 - val_accuracy: 0.6279 - val_loss: 1.0213
# Epoch 69/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 162s 717ms/step - accuracy: 0.6724 - loss: 0.8787 - val_accuracy: 0.6311 - val_loss: 1.0124
# Epoch 70/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 713ms/step - accuracy: 0.6832 - loss: 0.8585 - val_accuracy: 0.6302 - val_loss: 1.0210
# Epoch 71/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 713ms/step - accuracy: 0.6889 - loss: 0.8393 - val_accuracy: 0.6336 - val_loss: 1.0145
# Epoch 72/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 713ms/step - accuracy: 0.6896 - loss: 0.8468 - val_accuracy: 0.6223 - val_loss: 1.0310
# Epoch 73/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 711ms/step - accuracy: 0.6890 - loss: 0.8387 - val_accuracy: 0.6223 - val_loss: 1.0268
# Epoch 74/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 160s 710ms/step - accuracy: 0.6881 - loss: 0.8478 - val_accuracy: 0.6241 - val_loss: 1.0186
# Epoch 75/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 712ms/step - accuracy: 0.6930 - loss: 0.8205 - val_accuracy: 0.6234 - val_loss: 1.0144
# Epoch 76/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 163s 722ms/step - accuracy: 0.6840 - loss: 0.8570 - val_accuracy: 0.6326 - val_loss: 1.0180
# Epoch 77/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 162s 718ms/step - accuracy: 0.6971 - loss: 0.8248 - val_accuracy: 0.6311 - val_loss: 1.0178
# Epoch 78/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 167s 740ms/step - accuracy: 0.6994 - loss: 0.8176 - val_accuracy: 0.6350 - val_loss: 1.0233
# Epoch 79/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 164s 725ms/step - accuracy: 0.6950 - loss: 0.8266 - val_accuracy: 0.6325 - val_loss: 1.0091
# Epoch 80/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 162s 715ms/step - accuracy: 0.7017 - loss: 0.8129 - val_accuracy: 0.6306 - val_loss: 1.0219
# Epoch 81/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 162s 716ms/step - accuracy: 0.7058 - loss: 0.7992 - val_accuracy: 0.6349 - val_loss: 1.0198
# Epoch 82/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 170s 753ms/step - accuracy: 0.7023 - loss: 0.8064 - val_accuracy: 0.6363 - val_loss: 1.0183
# Epoch 83/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 165s 732ms/step - accuracy: 0.7096 - loss: 0.7979 - val_accuracy: 0.6333 - val_loss: 1.0191
# Epoch 84/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 714ms/step - accuracy: 0.7075 - loss: 0.8007 - val_accuracy: 0.6316 - val_loss: 1.0216
# Epoch 85/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 713ms/step - accuracy: 0.7102 - loss: 0.7931 - val_accuracy: 0.6332 - val_loss: 1.0237
# Epoch 86/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 711ms/step - accuracy: 0.7095 - loss: 0.7937 - val_accuracy: 0.6408 - val_loss: 1.0258
# Epoch 87/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 714ms/step - accuracy: 0.7155 - loss: 0.7717 - val_accuracy: 0.6347 - val_loss: 1.0259
# Epoch 88/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 162s 716ms/step - accuracy: 0.7115 - loss: 0.7865 - val_accuracy: 0.6285 - val_loss: 1.0325
# Epoch 89/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 161s 713ms/step - accuracy: 0.7118 - loss: 0.7755 - val_accuracy: 0.6315 - val_loss: 1.0263
# Epoch 90/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 159s 702ms/step - accuracy: 0.7138 - loss: 0.7804 - val_accuracy: 0.6248 - val_loss: 1.0367
# Epoch 91/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 163s 722ms/step - accuracy: 0.7310 - loss: 0.7479 - val_accuracy: 0.6292 - val_loss: 1.0373
# Epoch 92/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 159s 705ms/step - accuracy: 0.7219 - loss: 0.7643 - val_accuracy: 0.6281 - val_loss: 1.0311
# Epoch 93/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 160s 707ms/step - accuracy: 0.7222 - loss: 0.7580 - val_accuracy: 0.6308 - val_loss: 1.0358
# Epoch 94/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 159s 702ms/step - accuracy: 0.7213 - loss: 0.7524 - val_accuracy: 0.6340 - val_loss: 1.0275
# Epoch 95/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 158s 699ms/step - accuracy: 0.7278 - loss: 0.7541 - val_accuracy: 0.6305 - val_loss: 1.0251
# Epoch 96/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 158s 699ms/step - accuracy: 0.7233 - loss: 0.7529 - val_accuracy: 0.6228 - val_loss: 1.0393
# Epoch 97/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 159s 704ms/step - accuracy: 0.7262 - loss: 0.7504 - val_accuracy: 0.6366 - val_loss: 1.0253
# Epoch 98/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 159s 706ms/step - accuracy: 0.7254 - loss: 0.7538 - val_accuracy: 0.6323 - val_loss: 1.0353
# Epoch 99/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 166s 732ms/step - accuracy: 0.7273 - loss: 0.7458 - val_accuracy: 0.6329 - val_loss: 1.0248
# Epoch 100/100
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 162s 719ms/step - accuracy: 0.7334 - loss: 0.7278 - val_accuracy: 0.6245 - val_loss: 1.0468

# %%
model_json= model.to_json()
with open("emotiondetector.json","w") as json_file:
    json_file.write(model_json)
model.save("emotiondetector.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import model_from_json

# %%
json_file= open("emotiondetector.json","r")
model_json= json_file.read()
json_file.close()
model= model_from_json(model_json)
model.load_weights("emotiondetector.h5")

# %%
label= ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img= load_img(image,grayscale= True)
    feature=np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
image='images/train/angry/27.jpg'
print("OG is ANGRY")
img= ef(image)
pred= model.predict(img)
pred_label= label[pred.argmax()]
print("Model predicted : ", pred_label)
# Out:
# OG is ANGRY
# C:\Users\KIIT\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Model predicted :  angry

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image='images/train/angry/10.jpg'
print("OG is ANGRY")
img= ef(image)
pred= model.predict(img)
pred_label= label[pred.argmax()]
print("Model predicted : ", pred_label)
plt.imshow(img.reshape(48,48), cmap="gray")
# Out:
# OG is ANGRY
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Model predicted :  angry
